# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#drive.flush_and_unmount()

# %%
#importing libraries
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import GlobalMaxPooling2D, AveragePooling2D, MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l1,l2,l1_l2
from keras.optimizers import Adam, RMSprop
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np
from keras import backend as K
import matplotlib.pyplot as plt
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from keras import regularizers
from keras.callbacks import History,CSVLogger, TensorBoard, ReduceLROnPlateau

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((256, 256))
image_size = 0
#directory_root = 'C:/Users/Baba/Leaf_disease_detection/PlantVillage'
width = 256
height = 256
depth = 3  
bnEps=2e-5
bnMom=0.9
reg=0.0001

# %%
# Initialising the CNN
classifier = Sequential()

inputShape = (height, width, depth)
chanDim = -1
if K.image_data_format() == "channels_first":
    inputShape = (depth, height, width)
    chanDim = 1

# Step 1 - Convolution
classifier.add(Conv2D(64, (3, 3), input_shape = inputShape, padding = 'same'))
classifier.add(Activation("relu"))
classifier.add(MaxPooling2D())

# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), padding = 'same'))
classifier.add(Activation("relu"))
classifier.add(MaxPooling2D())

# Adding a third convolutional layer
classifier.add(Conv2D(128, (3, 3), padding = 'same'))
classifier.add(Activation("relu"))
classifier.add(MaxPooling2D())

# %%
# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 512))
classifier.add(Activation("relu"))

classifier.add(Dense(units = 256))
classifier.add(Activation("relu"))

classifier.add(Dense(units = 128))
classifier.add(Activation("relu"))

classifier.add(Dense(units = 3, activation = 'softmax'))
classifier.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 256, 256, 64)      1792
# _________________________________________________________________
# activation_25 (Activation)   (None, 256, 256, 64)      0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 128, 128, 32)      18464
# _________________________________________________________________
# activation_26 (Activation)   (None, 128, 128, 32)      0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 64, 64, 128)       36992
# _________________________________________________________________
# activation_27 (Activation)   (None, 64, 64, 128)       0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 131072)            0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               67109376
# _________________________________________________________________
# activation_28 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               131328
# _________________________________________________________________
# activation_29 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               32896
# _________________________________________________________________
# activation_30 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 67,331,235
# Trainable params: 67,331,235
# Non-trainable params: 0
# _________________________________________________________________

# %%
#opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
#opt = RMSprop(lr = 1e-4, decay = 1e-6)
# Compiling the CNN
#classifier.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
# Part 2 - Fitting the CNN to the images



from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=25, width_shift_range=0.1,
                                   height_shift_range=0.1, shear_range=0.2, 
                                   zoom_range=0.2,horizontal_flip=True, 
                                   brightness_range=[0.5, 1.5], channel_shift_range=0.05,
                                   fill_mode="nearest")

validation_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/PLD/Training',
                                                 target_size = (height, width),
                                                 batch_size = BS,
                                                 class_mode = 'categorical')

validation_set = validation_datagen.flow_from_directory('/content/drive/MyDrive/PLD/Validation',
                                            target_size = (height, width),
                                            batch_size = BS,
                                            class_mode = 'categorical')
print(training_set.samples)
# Out:
# Found 3252 images belonging to 3 classes.
# Found 399 images belonging to 3 classes.
# 3252

# %%
# keras model is saved using ModelCheckpoint
# weight is the name of folder
# model is saved with the name 'weights.{epoch:02d}.{accuracy:.4f}.hdf5
# model is saved if the new accuracy is better than previous one
ckpt_callback = ModelCheckpoint(filepath=os.path.join('/content/drive/MyDrive/PDDCNN_PLD_With_Data_Augmentation/weight', 'weights.{epoch:02d}.{accuracy:.4f}.hdf5'), 
                                monitor = 'val_accuracy', save_best_only=True)

early = EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=1, mode='auto')
#early stopping in case the loss stops decreasing

reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, patience = 10, verbose = 1, min_delta =0.00001)

csvlogger=CSVLogger("/content/drive/MyDrive/PDDCNN_PLD_With_Data_Augmentation/history/training_csv.csv", append=True)

# %%
# this is the directory where weights are saved
checkpoint_path = '/content/drive/MyDrive/PDDCNN_PLD_With_Data_Augmentation/weight'

# this is function to load weight file for resuming training from last epoch
def checkpoint_function():
    # if there is no file being saved in the checkpoint path then routine will go to loop model.fit(X, y, epochs=150, batch_size=1, callbacks=[ckpt_callback])
    # this signifies that no file is saved in the checkpoint path and let us begin the training from the first epoch.
    if not os.listdir(checkpoint_path):
        return
    # this loop will fetch epochs number in a list    
    files_int = list()
    for i in os.listdir(checkpoint_path):
        epoch = int(i.split('.')[1])
        files_int.append(epoch)
    # getting the maximum value for an epoch from the list
    # this is reference value and will help to find the file with that value    
    max_value = max(files_int)
    # conditions are applied to find the file which has the maximum value of epoch
    # such file would be the last file where the training is stopped and we would like to resume the training from that point.
    for i in os.listdir(checkpoint_path):
        epoch = int(i.split('.')[1])
        if epoch > max_value:
            pass
        elif epoch < max_value:
            pass
        else:
            final_file = i    
    # in the end we will get the epoch as well as file         
    return final_file, max_value

# %%
checkpoint_path_file = checkpoint_function()
# this is interesting loop of the code. Code has been divided into conditions here
# in the if condition if checkpoint is not none, then file and last epcoh is restored
# Such file is loaded using load_model and training start from that epoch
if checkpoint_path_file is not None:
     # Load model:
    checkpoint_path_file = checkpoint_function()[0]
    max_value = checkpoint_function()[1]

    classifier = load_model(os.path.join(checkpoint_path, checkpoint_path_file))
    #model.fit(X, y, epochs=150, batch_size=1, callbacks=[ckpt_callback], initial_epoch = max_value)
    print(max_value)
    history = classifier.fit(training_set,
                         epochs = EPOCHS,
                         initial_epoch = max_value,
                         validation_data = validation_set,
                         callbacks=[ckpt_callback,reduce_lr,csvlogger])
# if there is no checkpoint_path_file it means no file is saved and hence model will be trained from scratch
# file is saved in form of .hdf5 extension 
else:
    #model.fit(X, y, epochs=150, batch_size=1, callbacks=[ckpt_callback])
     history = classifier.fit(training_set,
                         epochs = EPOCHS,
                         validation_data = validation_set,
                         callbacks=[ckpt_callback,reduce_lr,csvlogger])
# Out:
# Epoch 1/100
# 102/102 [==============================] - 63s 609ms/step - loss: 1.3029 - accuracy: 0.3983 - val_loss: 0.9245 - val_accuracy: 0.5815
# Epoch 2/100
# 102/102 [==============================] - 64s 630ms/step - loss: 0.9292 - accuracy: 0.5618 - val_loss: 0.6654 - val_accuracy: 0.6667
# Epoch 3/100
# 102/102 [==============================] - 66s 643ms/step - loss: 0.7047 - accuracy: 0.7165 - val_loss: 0.6695 - val_accuracy: 0.7368
# Epoch 4/100
# 102/102 [==============================] - 67s 654ms/step - loss: 0.7018 - accuracy: 0.6969 - val_loss: 0.4618 - val_accuracy: 0.8045
# Epoch 5/100
# 102/102 [==============================] - 67s 657ms/step - loss: 0.5100 - accuracy: 0.7918 - val_loss: 0.3407 - val_accuracy: 0.8747
# Epoch 6/100
# 102/102 [==============================] - 66s 650ms/step - loss: 0.4663 - accuracy: 0.8139 - val_loss: 0.3987 - val_accuracy: 0.8697
# Epoch 7/100
# 102/102 [==============================] - 65s 634ms/step - loss: 0.4932 - accuracy: 0.7942 - val_loss: 0.2943 - val_accuracy: 0.8897
# Epoch 8/100
# 102/102 [==============================] - 67s 650ms/step - loss: 0.4162 - accuracy: 0.8315 - val_loss: 0.2851 - val_accuracy: 0.9098
# Epoch 9/100
# 102/102 [==============================] - 66s 648ms/step - loss: 0.3727 - accuracy: 0.8493 - val_loss: 0.3010 - val_accuracy: 0.8997
# Epoch 10/100
# 102/102 [==============================] - 64s 631ms/step - loss: 0.3404 - accuracy: 0.8765 - val_loss: 0.2321 - val_accuracy: 0.9073
# Epoch 11/100
# 102/102 [==============================] - 65s 632ms/step - loss: 0.3027 - accuracy: 0.8916 - val_loss: 0.2411 - val_accuracy: 0.8847
# Epoch 12/100
# 102/102 [==============================] - 64s 630ms/step - loss: 0.3013 - accuracy: 0.8883 - val_loss: 0.1705 - val_accuracy: 0.9323
# Epoch 13/100
# 102/102 [==============================] - 66s 641ms/step - loss: 0.2495 - accuracy: 0.9157 - val_loss: 0.2527 - val_accuracy: 0.9098
# Epoch 14/100
# 102/102 [==============================] - 63s 622ms/step - loss: 0.2335 - accuracy: 0.9121 - val_loss: 0.1549 - val_accuracy: 0.9424
# Epoch 15/100
# 102/102 [==============================] - 65s 638ms/step - loss: 0.2717 - accuracy: 0.9139 - val_loss: 0.1671 - val_accuracy: 0.9499
# Epoch 16/100
# 102/102 [==============================] - 63s 620ms/step - loss: 0.2068 - accuracy: 0.9237 - val_loss: 0.1466 - val_accuracy: 0.9549
# Epoch 17/100
# 102/102 [==============================] - 79s 778ms/step - loss: 0.2043 - accuracy: 0.9252 - val_loss: 0.1999 - val_accuracy: 0.9223
# Epoch 18/100
# 102/102 [==============================] - 65s 634ms/step - loss: 0.2254 - accuracy: 0.9222 - val_loss: 0.1423 - val_accuracy: 0.9574
# Epoch 19/100
# 102/102 [==============================] - 67s 654ms/step - loss: 0.2100 - accuracy: 0.9259 - val_loss: 0.1898 - val_accuracy: 0.9348
# Epoch 20/100
# 102/102 [==============================] - 65s 639ms/step - loss: 0.1792 - accuracy: 0.9402 - val_loss: 0.2254 - val_accuracy: 0.9123
# Epoch 21/100
# 102/102 [==============================] - 66s 643ms/step - loss: 0.2245 - accuracy: 0.9118 - val_loss: 0.1173 - val_accuracy: 0.9549
# Epoch 22/100
# 102/102 [==============================] - 66s 643ms/step - loss: 0.1680 - accuracy: 0.9336 - val_loss: 0.1103 - val_accuracy: 0.9649
# Epoch 23/100
# 102/102 [==============================] - 67s 652ms/step - loss: 0.1568 - accuracy: 0.9456 - val_loss: 0.1959 - val_accuracy: 0.9273
# Epoch 24/100
# 102/102 [==============================] - 65s 635ms/step - loss: 0.1844 - accuracy: 0.9315 - val_loss: 0.0918 - val_accuracy: 0.9699
# Epoch 25/100
# 102/102 [==============================] - 66s 650ms/step - loss: 0.1673 - accuracy: 0.9400 - val_loss: 0.1073 - val_accuracy: 0.9574
# Epoch 26/100
# 102/102 [==============================] - 65s 638ms/step - loss: 0.1359 - accuracy: 0.9520 - val_loss: 0.1237 - val_accuracy: 0.9599
# Epoch 27/100
# 102/102 [==============================] - 65s 639ms/step - loss: 0.1712 - accuracy: 0.9439 - val_loss: 0.1111 - val_accuracy: 0.9549
# Epoch 28/100
# 102/102 [==============================] - 65s 639ms/step - loss: 0.1536 - accuracy: 0.9476 - val_loss: 0.0999 - val_accuracy: 0.9599
# Epoch 29/100
# 102/102 [==============================] - 66s 649ms/step - loss: 0.1603 - accuracy: 0.9412 - val_loss: 0.1085 - val_accuracy: 0.9549
# Epoch 30/100
# 102/102 [==============================] - 66s 644ms/step - loss: 0.1372 - accuracy: 0.9527 - val_loss: 0.1063 - val_accuracy: 0.9574
# Epoch 31/100
# 102/102 [==============================] - 66s 649ms/step - loss: 0.1430 - accuracy: 0.9505 - val_loss: 0.0924 - val_accuracy: 0.9649
# Epoch 32/100
# 102/102 [==============================] - 66s 645ms/step - loss: 0.1284 - accuracy: 0.9513 - val_loss: 0.1739 - val_accuracy: 0.9549
# Epoch 33/100
# 102/102 [==============================] - 65s 641ms/step - loss: 0.1718 - accuracy: 0.9426 - val_loss: 0.1249 - val_accuracy: 0.9549
# Epoch 34/100
# 102/102 [==============================] - 66s 650ms/step - loss: 0.1440 - accuracy: 0.9509 - val_loss: 0.1008 - val_accuracy: 0.9599
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 35/100
# 102/102 [==============================] - 67s 653ms/step - loss: 0.0734 - accuracy: 0.9740 - val_loss: 0.0844 - val_accuracy: 0.9549
# Epoch 36/100
# 102/102 [==============================] - 66s 646ms/step - loss: 0.0936 - accuracy: 0.9656 - val_loss: 0.0993 - val_accuracy: 0.9574
# Epoch 37/100
# 102/102 [==============================] - 64s 631ms/step - loss: 0.0734 - accuracy: 0.9750 - val_loss: 0.0881 - val_accuracy: 0.9649
# Epoch 38/100
# 102/102 [==============================] - 63s 619ms/step - loss: 0.0870 - accuracy: 0.9715 - val_loss: 0.0969 - val_accuracy: 0.9649
# Epoch 39/100
# 102/102 [==============================] - 62s 611ms/step - loss: 0.0745 - accuracy: 0.9725 - val_loss: 0.0846 - val_accuracy: 0.9649
# Epoch 40/100
# 102/102 [==============================] - 62s 604ms/step - loss: 0.0734 - accuracy: 0.9742 - val_loss: 0.0783 - val_accuracy: 0.9599
# Epoch 41/100
# 102/102 [==============================] - 63s 619ms/step - loss: 0.0696 - accuracy: 0.9719 - val_loss: 0.0784 - val_accuracy: 0.9624
# Epoch 42/100
# 102/102 [==============================] - 64s 624ms/step - loss: 0.0789 - accuracy: 0.9707 - val_loss: 0.0975 - val_accuracy: 0.9674
# Epoch 43/100
# 102/102 [==============================] - 64s 629ms/step - loss: 0.0924 - accuracy: 0.9664 - val_loss: 0.0700 - val_accuracy: 0.9699
# Epoch 44/100
# 102/102 [==============================] - 64s 625ms/step - loss: 0.0726 - accuracy: 0.9726 - val_loss: 0.0767 - val_accuracy: 0.9624
# Epoch 45/100
# 102/102 [==============================] - 63s 618ms/step - loss: 0.0856 - accuracy: 0.9716 - val_loss: 0.0810 - val_accuracy: 0.9674
# Epoch 46/100
# 102/102 [==============================] - 62s 610ms/step - loss: 0.0560 - accuracy: 0.9828 - val_loss: 0.0817 - val_accuracy: 0.9649
# Epoch 47/100
# 102/102 [==============================] - 62s 603ms/step - loss: 0.0764 - accuracy: 0.9706 - val_loss: 0.0699 - val_accuracy: 0.9799
# Epoch 48/100
# 102/102 [==============================] - 63s 615ms/step - loss: 0.0730 - accuracy: 0.9764 - val_loss: 0.0750 - val_accuracy: 0.9724
# Epoch 49/100
# 102/102 [==============================] - 61s 598ms/step - loss: 0.0731 - accuracy: 0.9717 - val_loss: 0.0689 - val_accuracy: 0.9699
# Epoch 50/100
# 102/102 [==============================] - 61s 594ms/step - loss: 0.0513 - accuracy: 0.9782 - val_loss: 0.0863 - val_accuracy: 0.9674
# Epoch 51/100
# 102/102 [==============================] - 61s 599ms/step - loss: 0.0699 - accuracy: 0.9772 - val_loss: 0.0696 - val_accuracy: 0.9749
# Epoch 52/100
# 102/102 [==============================] - 61s 599ms/step - loss: 0.0674 - accuracy: 0.9742 - val_loss: 0.0760 - val_accuracy: 0.9674
# Epoch 53/100
# 102/102 [==============================] - 62s 604ms/step - loss: 0.0680 - accuracy: 0.9751 - val_loss: 0.0771 - val_accuracy: 0.9749
# Epoch 54/100
# 102/102 [==============================] - 61s 597ms/step - loss: 0.0704 - accuracy: 0.9717 - val_loss: 0.0625 - val_accuracy: 0.9774
# Epoch 55/100
# 102/102 [==============================] - 61s 597ms/step - loss: 0.0654 - accuracy: 0.9795 - val_loss: 0.0890 - val_accuracy: 0.9574
# Epoch 56/100
# 102/102 [==============================] - 61s 602ms/step - loss: 0.0612 - accuracy: 0.9773 - val_loss: 0.0936 - val_accuracy: 0.9649
# Epoch 57/100
# 102/102 [==============================] - 61s 596ms/step - loss: 0.0781 - accuracy: 0.9676 - val_loss: 0.0986 - val_accuracy: 0.9674
# Epoch 58/100
# 102/102 [==============================] - 61s 593ms/step - loss: 0.0563 - accuracy: 0.9776 - val_loss: 0.0707 - val_accuracy: 0.9724
# Epoch 59/100
# 102/102 [==============================] - 61s 599ms/step - loss: 0.0493 - accuracy: 0.9812 - val_loss: 0.1035 - val_accuracy: 0.9624
# Epoch 60/100
# 102/102 [==============================] - 60s 592ms/step - loss: 0.0607 - accuracy: 0.9792 - val_loss: 0.0968 - val_accuracy: 0.9524
# Epoch 61/100
# 102/102 [==============================] - 61s 598ms/step - loss: 0.0608 - accuracy: 0.9807 - val_loss: 0.0827 - val_accuracy: 0.9749
# Epoch 62/100
# 102/102 [==============================] - 61s 598ms/step - loss: 0.0544 - accuracy: 0.9813 - val_loss: 0.0721 - val_accuracy: 0.9624
# Epoch 63/100
# 102/102 [==============================] - 62s 606ms/step - loss: 0.0574 - accuracy: 0.9826 - val_loss: 0.1101 - val_accuracy: 0.9649
# Epoch 64/100
# 102/102 [==============================] - 60s 590ms/step - loss: 0.0432 - accuracy: 0.9869 - val_loss: 0.0794 - val_accuracy: 0.9699
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 65/100
# 102/102 [==============================] - 60s 588ms/step - loss: 0.0397 - accuracy: 0.9841 - val_loss: 0.0703 - val_accuracy: 0.9724
# Epoch 66/100
# 102/102 [==============================] - 60s 590ms/step - loss: 0.0436 - accuracy: 0.9826 - val_loss: 0.0708 - val_accuracy: 0.9749
# Epoch 67/100
# 102/102 [==============================] - 60s 584ms/step - loss: 0.0506 - accuracy: 0.9838 - val_loss: 0.0795 - val_accuracy: 0.9749
# Epoch 68/100
# 102/102 [==============================] - 60s 591ms/step - loss: 0.0476 - accuracy: 0.9848 - val_loss: 0.0766 - val_accuracy: 0.9674
# Epoch 69/100
# 102/102 [==============================] - 60s 586ms/step - loss: 0.0475 - accuracy: 0.9820 - val_loss: 0.0681 - val_accuracy: 0.9724
# Epoch 70/100
# 102/102 [==============================] - 59s 579ms/step - loss: 0.0455 - accuracy: 0.9835 - val_loss: 0.0851 - val_accuracy: 0.9699
# Epoch 71/100
# 102/102 [==============================] - 60s 589ms/step - loss: 0.0648 - accuracy: 0.9795 - val_loss: 0.0767 - val_accuracy: 0.9724
# Epoch 72/100
# 102/102 [==============================] - 60s 590ms/step - loss: 0.0448 - accuracy: 0.9831 - val_loss: 0.0702 - val_accuracy: 0.9699
# Epoch 73/100
# 102/102 [==============================] - 61s 598ms/step - loss: 0.0452 - accuracy: 0.9826 - val_loss: 0.0801 - val_accuracy: 0.9699
# Epoch 74/100
# 102/102 [==============================] - 61s 594ms/step - loss: 0.0453 - accuracy: 0.9852 - val_loss: 0.0684 - val_accuracy: 0.9749
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 75/100
# 102/102 [==============================] - 61s 594ms/step - loss: 0.0534 - accuracy: 0.9808 - val_loss: 0.0684 - val_accuracy: 0.9774
# Epoch 76/100
# 102/102 [==============================] - 62s 604ms/step - loss: 0.0413 - accuracy: 0.9864 - val_loss: 0.0663 - val_accuracy: 0.9749
# Epoch 77/100
# 102/102 [==============================] - 61s 597ms/step - loss: 0.0576 - accuracy: 0.9796 - val_loss: 0.0663 - val_accuracy: 0.9724
# Epoch 78/100
# 102/102 [==============================] - 60s 592ms/step - loss: 0.0419 - accuracy: 0.9877 - val_loss: 0.0671 - val_accuracy: 0.9749
# Epoch 79/100
# 102/102 [==============================] - 61s 594ms/step - loss: 0.0345 - accuracy: 0.9899 - val_loss: 0.0683 - val_accuracy: 0.9774
# Epoch 80/100
# 102/102 [==============================] - 59s 581ms/step - loss: 0.0477 - accuracy: 0.9828 - val_loss: 0.0724 - val_accuracy: 0.9749
# Epoch 81/100
# 102/102 [==============================] - 60s 586ms/step - loss: 0.0507 - accuracy: 0.9820 - val_loss: 0.0691 - val_accuracy: 0.9774
# Epoch 82/100
# 102/102 [==============================] - 59s 580ms/step - loss: 0.0338 - accuracy: 0.9870 - val_loss: 0.0722 - val_accuracy: 0.9749
# Epoch 83/100
# 102/102 [==============================] - 59s 582ms/step - loss: 0.0542 - accuracy: 0.9839 - val_loss: 0.0721 - val_accuracy: 0.9774
# Epoch 84/100
# 102/102 [==============================] - 60s 589ms/step - loss: 0.0374 - accuracy: 0.9867 - val_loss: 0.0729 - val_accuracy: 0.9749
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 85/100
# 102/102 [==============================] - 60s 584ms/step - loss: 0.0349 - accuracy: 0.9859 - val_loss: 0.0722 - val_accuracy: 0.9749
# Epoch 86/100
# 102/102 [==============================] - 59s 583ms/step - loss: 0.0370 - accuracy: 0.9847 - val_loss: 0.0713 - val_accuracy: 0.9774
# Epoch 87/100
# 102/102 [==============================] - 60s 589ms/step - loss: 0.0417 - accuracy: 0.9843 - val_loss: 0.0705 - val_accuracy: 0.9774
# Epoch 88/100
# 102/102 [==============================] - 60s 585ms/step - loss: 0.0454 - accuracy: 0.9812 - val_loss: 0.0702 - val_accuracy: 0.9774
# Epoch 89/100
# 102/102 [==============================] - 60s 586ms/step - loss: 0.0329 - accuracy: 0.9897 - val_loss: 0.0710 - val_accuracy: 0.9774
# Epoch 90/100
# 102/102 [==============================] - 60s 589ms/step - loss: 0.0336 - accuracy: 0.9887 - val_loss: 0.0707 - val_accuracy: 0.9774
# Epoch 91/100
# 102/102 [==============================] - 60s 592ms/step - loss: 0.0425 - accuracy: 0.9813 - val_loss: 0.0704 - val_accuracy: 0.9749
# Epoch 92/100
# 102/102 [==============================] - 60s 591ms/step - loss: 0.0378 - accuracy: 0.9876 - val_loss: 0.0701 - val_accuracy: 0.9774
# Epoch 93/100
# 102/102 [==============================] - 59s 582ms/step - loss: 0.0353 - accuracy: 0.9897 - val_loss: 0.0702 - val_accuracy: 0.9774
# Epoch 94/100
#  34/102 [=========>....................] - ETA: 38s - loss: 0.0504 - accuracy: 0.9829

# %%
classifier.save("/content/drive/MyDrive/PDDCNN_PLD_With_Data_Augmentation/PDDCNN_PLD_with_Augmentation.h5")
print("Save Model")

# %%
def show_final_history(history):
    fig, ax = plt.subplots(1, 2, figsize=(15,5))
    ax[0].set_title('PDDCNN Model Loss on PLD Dataset with Data Augmentation')
    ax[0].plot(history.epoch, history.history["loss"], label="Training Loss")
    ax[0].plot(history.epoch, history.history["val_loss"], label="Validation Loss")
    ax[1].set_title('PDDCNN Model Accuracy on PLD Dataset with Data Augmentation')
    ax[1].plot(history.epoch, history.history["accuracy"], label="Training Accuracy")
    ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax[0].legend()
    ax[1].legend()

# %%
show_final_history(history)

# %%
a=classifier.evaluate(training_set)
b=classifier.evaluate(test_set)
# c=model.evaluate(x_val,y_val)

print(a)
print(b)
# print(c)
ind=0
# Out:
# 102/102 [==============================] - 279s 3s/step - loss: 0.0244 - accuracy: 0.9914
# 13/13 [==============================] - 27s 2s/step - loss: 0.0529 - accuracy: 0.9804
# [0.02441033534705639, 0.9914084076881409]
# [0.05287071689963341, 0.980440080165863]

# %%
class CustomEarlyStopping(keras.callbacks.Callback):
    def __init__(self, patience=0):
        super(CustomEarlyStopping, self).__init__()
        self.patience = patience
        self.best_weights = None
        
    def on_train_begin(self, logs=None):
        # The number of epoch it has waited when loss is no longer minimum.
        self.wait = 0
        # The epoch the training stops at.
        self.stopped_epoch = 0
        # Initialize the best as infinity.
        self.best_v_loss = np.Inf
        self.best_map10 = 0

    def on_epoch_end(self, epoch, logs=None): 
        v_loss=logs.get('val_loss')
        map10=logs.get('val_average_precision_at_k10')

        # If BOTH the validation loss AND map10 does not improve for 'patience' epochs, stop training early.
        if np.less(v_loss, self.best_v_loss) and np.greater(map10, self.best_map10):
            self.best_v_loss = v_loss
            self.best_map10 = map10
            self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.stopped_epoch = epoch
                self.model.stop_training = True
                print("Restoring model weights from the end of the best epoch.")
                self.model.set_weights(self.best_weights)
                
    def on_train_end(self, logs=None):
        if self.stopped_epoch > 0:
            print("Epoch %05d: early stopping" % (self.stopped_epoch + 1))

# %%
model.fit(
    x_train,
    y_train,
    batch_size=64,
    steps_per_epoch=5,
    epochs=30,
    verbose=0,
    callbacks=[CustomEarlyStopping(patience=10)]
)

# %%
from google.colab import files
files.download("model.h5")
